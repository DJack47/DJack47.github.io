# %% [markdown]
# <a href="https://colab.research.google.com/github/DJack47/DJack47.github.io/blob/main/Modeling%20Copper%20Depletion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given data
population = np.array([6.148898975, 6.230746982, 6.31240736, 6.393898365, 6.475751478, 6.558176119,
                       6.641416218, 6.725948544, 6.811597272, 6.898305908, 6.985603105, 7.073125425,
                       7.161697921, 7.25059337, 7.339013419, 7.426597537, 7.513474238, 7.599822404,
                       7.683789828, 7.764951032, 7.84095288, 7.909295151, 7.975105156])

production = np.array([14.793,	15.638,	15.354,	15.272,	15.918,	16.572,	17.288,	17.895,	18.191,	18.234,
                       18.981,	19.601,	20.194,	21.058,	22.49,	22.838,	23.356,	23.551,	24.062,	24.086,
                       24.546,	24.823,	25.664])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, population, production)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Predict production using the fitted model
predicted_production = power_law_model(population, k, alpha)

# Calculate R^2 value
r_squared = r2_score(production, predicted_production)
print("R^2 value:", r_squared)

# Calculate residuals
residuals = production - predicted_production

# Plotting the original data and the fitted model
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(population, production, color='blue', label='Actual Data')
plt.plot(population, predicted_production, marker='o', color='red', label='Fitted Model')
plt.title('Fitted Power-law Model for Copper Production vs Population')
plt.xlabel('Population (billions)')
plt.ylabel('Production (Mt)')
plt.legend()
plt.grid(True)

# Plotting the residual plot
plt.subplot(1, 2, 2)
plt.scatter(population, residuals, color='green')
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('Population (billions)')
plt.ylabel('Residuals')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Fitted Parameters:
# k: 0.262471870241196
# alpha: 2.2109461701252426
# R^2 value: 0.9851183998721763

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given data
gdp = np.array([33845.58, 33631.01, 34925.12, 39161.65, 44133.62, 47793.59, 51791.10, 58361.10,
                64135.19, 60817.92, 66619.78, 73881.74, 75525.95, 77635.15, 79756.52, 75215.06,
                76486.45, 81442.05, 86502.22, 87728.10, 85215.15, 96882.40, 100562.01,])

production = np.array([14.793,	15.638,	15.354,	15.272,	15.918,	16.572,	17.288,	17.895,	18.191,	18.234,
                       18.981,	19.601,	20.194,	21.058,	22.49,	22.838,	23.356,	23.551,	24.062,	24.086,
                       24.546,	24.823,	25.664])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, gdp, production)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Predict production using the fitted model
predicted_production = power_law_model(gdp, k, alpha)

# Plotting the original data and the fitted model
plt.figure(figsize=(10, 6))
plt.scatter(gdp, production, color='blue', label='Actual Data')
plt.plot(gdp, predicted_production, color='red', label='Fitted Model')
plt.title('Fitted Power-law Model for Copper Production vs GDP')
plt.xlabel('GDP (billions of dollars)')
plt.ylabel('Production (Mt)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitted Parameters:
# k: 0.050242793355471396
# alpha: 0.5401656532737643

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

# Given data
gdp = np.array([33845.58, 33631.01, 34925.12, 39161.65, 44133.62, 47793.59, 51791.10, 58361.10,
                64135.19, 60817.92, 66619.78, 73881.74, 75525.95, 77635.15, 79756.52, 75215.06,
                76486.45, 81442.05, 86502.22, 87728.10, 85215.15, 96882.40, 100562.01,])

production = np.array([14.793,	15.638,	15.354,	15.272,	15.918,	16.572,	17.288,	17.895,	18.191,	18.234,
                       18.981,	19.601,	20.194,	21.058,	22.49,	22.838,	23.356,	23.551,	24.062,	24.086,
                       24.546,	24.823,	25.664])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, gdp, production)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Predict production using the fitted model
predicted_production = power_law_model(gdp, k, alpha)

# Calculate R^2 value
r_squared = r2_score(production, predicted_production)
print("R^2 value:", r_squared)

# Calculate residuals
residuals = production - predicted_production

# Plotting the original data and the fitted model
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(gdp, production, color='blue', label='Actual Data')
plt.plot(gdp, predicted_production, marker='o', color='red', label='Fitted Model')
plt.title('Fitted Power-law Model for Copper Production vs GDP')
plt.xlabel('GDP (billions of dollars)')
plt.ylabel('Production (Mt)')
plt.legend()
plt.grid(True)

# Plotting the residual plot
plt.subplot(1, 2, 2)
plt.scatter(gdp, residuals, color='green')
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('GDP (billions of dollars)')
plt.ylabel('Residuals')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Fitted Parameters:
# k: 0.050242793355471396
# alpha: 0.5401656532737643
# R^2 value: 0.9116411682941229

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

# Given data
gdp = np.array([33845.58, 33631.01, 34925.12, 39161.65, 44133.62, 47793.59, 51791.10, 58361.10,
                64135.19, 60817.92, 66619.78, 73881.74, 75525.95, 77635.15, 79756.52, 75215.06,
                76486.45, 81442.05, 86502.22, 87728.10, 85215.15, 96882.40, 100562.01,])

mining = np.array([13.2,	13.7,	13.6,	13.6,	14.6,	15,	15.1,	15.4,	15.4,	15.9,	15.9,	16.1,	16.9,
                   18.3,	18.5,	19.1,	20.1,	20,	20.4,	20.4,	20.6,	21.2,	21.9])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, gdp, mining)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Predict mining using the fitted model
predicted_mining = power_law_model(gdp, k, alpha)

# Calculate R^2 value
r_squared = r2_score(mining, predicted_mining)
print("R^2 value:", r_squared)

# Calculate residuals
residuals = mining - predicted_mining

# Plotting the original data and the fitted model
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(gdp, mining, color='blue', label='Actual Data')
plt.plot(gdp, predicted_mining, marker='o', color='red', label='Fitted Model')
plt.title('Fitted Power-law Model for Copper Mining vs GDP')
plt.xlabel('GDP (billions of dollars)')
plt.ylabel('Mining (Mt)')
plt.legend()
plt.grid(True)

# Plotting the residual plot
plt.subplot(1, 2, 2)
plt.scatter(gdp, residuals, color='green')
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('GDP (billions of dollars)')
plt.ylabel('Residuals')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Fitted Parameters:
# k: 0.08669435147585441
# alpha: 0.477246177267269
# R^2 value: 0.869644104363953

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

# Given data
population = np.array([6.148898975, 6.230746982, 6.31240736, 6.393898365, 6.475751478, 6.558176119,
                       6.641416218, 6.725948544, 6.811597272, 6.898305908, 6.985603105, 7.073125425,
                       7.161697921, 7.25059337, 7.339013419, 7.426597537, 7.513474238, 7.599822404,
                       7.683789828, 7.764951032, 7.84095288, 7.909295151, 7.975105156])

mining = np.array([13.2,	13.7,	13.6,	13.6,	14.6,	15,	15.1,	15.4,	15.4,	15.9,	15.9,	16.1,	16.9,
                   18.3,	18.5,	19.1,	20.1,	20,	20.4,	20.4,	20.6,	21.2,	21.9])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, population, mining)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Predict mining using the fitted model
predicted_mining = power_law_model(population, k, alpha)

# Calculate R^2 value
r_squared = r2_score(mining, predicted_mining)
print("R^2 value:", r_squared)

# Calculate residuals
residuals = mining - predicted_mining

# Plotting the original data and the fitted model
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(population, mining, color='blue', label='Actual Data')
plt.plot(population, predicted_mining, marker='o', color='red', label='Fitted Model')
plt.title('Fitted Power-law Model for Copper Mining vs Population')
plt.xlabel('Population (billions)')
plt.ylabel('Mining (Mt)')
plt.legend()
plt.grid(True)

# Plotting the residual plot
plt.subplot(1, 2, 2)
plt.scatter(population, residuals, color='green')
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('Population (billions)')
plt.ylabel('Residuals')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Fitted Parameters:
# k: 0.33518286439765077
# alpha: 2.008507433624112
# R^2 value: 0.9765937315681392

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given data
population = np.array([6.148898975, 6.230746982, 6.31240736, 6.393898365, 6.475751478, 6.558176119,
                       6.641416218, 6.725948544, 6.811597272, 6.898305908, 6.985603105, 7.073125425,
                       7.161697921, 7.25059337, 7.339013419, 7.426597537, 7.513474238, 7.599822404,
                       7.683789828, 7.764951032, 7.84095288, 7.909295151, 7.975105156])

consumption = np.array([15.122,	14.938,	15.133,	15.641,	16.743,	16.552,	16.917,	18.026,	17.877,	17.87,
                        19.136,	19.709,	20.479,	21.408,	22.906,	23.046,	23.481,	23.686,	24.466,	24.321,
                        24.945,	25.204,	26.069])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, population, consumption)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Predict consumption using the fitted model
predicted_consumption = power_law_model(population, k, alpha)

# Calculate R^2 value
r_squared = r2_score(consumption, predicted_consumption)
print("R^2 value:", r_squared)

# Calculate residuals
residuals = consumption - predicted_consumption

# Plotting the original data and the fitted model
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(population, consumption, color='blue', label='Actual Data')
plt.plot(population, predicted_consumption, marker='o', color='red', label='Fitted Model')
plt.title('Fitted Power-law Model for Copper Consumption vs Population')
plt.xlabel('Population (billions)')
plt.ylabel('Consumption (Mt)')
plt.legend()
plt.grid(True)

# Plotting the residual plot
plt.subplot(1, 2, 2)
plt.scatter(population, residuals, color='green')
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('Population (billions)')
plt.ylabel('Residuals')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Fitted Parameters:
# k: 0.22920129758714317
# alpha: 2.283428131652162
# R^2 value: 0.9828180339050826

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given data
gdp = np.array([33845.58, 33631.01, 34925.12, 39161.65, 44133.62, 47793.59, 51791.10, 58361.10,
                64135.19, 60817.92, 66619.78, 73881.74, 75525.95, 77635.15, 79756.52, 75215.06,
                76486.45, 81442.05, 86502.22, 87728.10, 85215.15, 96882.40, 100562.01,])

consumption = np.array([15.122,	14.938,	15.133,	15.641,	16.743,	16.552,	16.917,	18.026,	17.877,	17.87,
                        19.136,	19.709,	20.479,	21.408,	22.906,	23.046,	23.481,	23.686,	24.466,	24.321,
                        24.945,	25.204,	26.069])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, gdp, consumption)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Predict consumption using the fitted model
predicted_consumption = power_law_model(gdp, k, alpha)

# Calculate R^2 value
r_squared = r2_score(consumption, predicted_consumption)
print("R^2 value:", r_squared)

# Calculate residuals
residuals = consumption - predicted_consumption

# Plotting the original data and the fitted model
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(gdp, consumption, color='blue', label='Actual Data')
plt.plot(gdp, predicted_consumption, marker='o', color='red', label='Fitted Model')
plt.title('Fitted Power-law Model for Copper Consumption vs GDP')
plt.xlabel('GDP (billions of dollars)')
plt.ylabel('Consumption (Mt)')
plt.legend()
plt.grid(True)

# Plotting the residual plot
plt.subplot(1, 2, 2)
plt.scatter(gdp, residuals, color='green')
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('GDP (billions of dollars)')
plt.ylabel('Residuals')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Fitted Parameters:
# k: 0.04089713046093491
# alpha: 0.5593172869402829
# R^2 value: 0.9101080202509474

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data
years = np.arange(2022, 2101)
mining = np.array([21.69909423,	22.08446315,	22.49169805,	22.90058002,	23.30876259,	23.71620665,	24.12280408,	24.52827762,	24.93240634,	25.33476801,
                   25.73540948,	26.13409129,	26.53022867,	26.92354587,	27.31355566,	27.70026799,	28.08375694,	28.46306402,	28.83746909,	29.20693028,
                   29.57109695,	29.92928264,	30.28079837,	30.62503914,	30.96151292,	31.28971727,	31.60889559,	31.91819127,	32.21722834,	32.50554472,
                   32.78358612,	33.05143439,	33.30872158,	33.55588725,	33.79314412,	34.0209554,	34.23959221,	34.44877075,	34.64913208,	34.84183949,
                   35.02740421,	35.20584618,	35.37722173,	35.54121859,	35.69757568,	35.84726423,	35.99006956,	36.1254843,	36.2533045,	36.37344447,
                   36.48627775,	36.59157135,	36.68869102,	36.77725118,	36.85696789,	36.92760244,	36.98949088,	37.0432062,	37.08875675,	37.12606248,
                   37.15592039,	37.17885847,	37.19476566,	37.20358884,	37.20535961,	37.20064116,	37.1903479,	37.1743809,	37.15247074,	37.12460005,
                   37.09106453,	37.05195741,	37.00751076,	36.95775452,	36.90216424,	36.84062761,	36.77334103,	36.70090367,	36.6230616])

production = np.array([25.86892339,	26.37509419,	26.91095321,	27.44996409,	27.98902124,	28.52805268,	29.06689523,	29.60516063,	30.14253379,	30.67843004,
                       31.21288811,	31.745565,	32.27565404,	32.80275901,	33.32619839,	33.84595644,	34.36210477,	34.87332382,	35.37860984,	35.8778723,
                       36.37060339,	36.8558389,	37.33260795,	37.8000507,	38.25745873,	38.70410807,	39.13892711,	39.56070533,	39.96888602,	40.36279484,
                       40.74299927,	41.10957267,	41.46197436,	41.80077125,	42.12622254,	42.43893386,	42.73925012,	43.0267556,	43.30230729,	43.56748427,
                       43.82297222,	44.06878216,	44.3049761,	44.53110853,	44.74680458,	44.95339052,	45.15055795,	45.33759423,	45.5142057,	45.68026247,
                       45.83627032,	45.98189737,	46.11625684,	46.23880599,	46.34914303,	46.44692944,	46.53262323,	46.60701182,	46.67010181,	46.72177811,
                       46.76314137,	46.79492061,	46.81696015,	46.82918516,	46.83163869,	46.82510094,	46.81083921,	46.78871706,	46.75836227,	46.71975224,
                       46.67329843,	46.61913213,	46.55757717,	46.48867769,	46.41171064,	46.32652427,	46.23339451,	46.13315488,	46.02545838])

consumption = np.array([26.25666424,	26.78743821,	27.34970743,	27.91565438,	28.48201452,	29.04870544,	29.61554884,	30.18212927,
                        30.74810759,	31.31286003,	31.87641915,	32.43841508,	32.9979878,	33.55470942,	34.10784988,	34.65738212,
                        35.2033718,	35.74441239,	36.27942952,	36.80831484,	37.33051797,	37.84500398,	38.35072956,	38.8467681,	39.33235283,
                        39.80669989,	40.26865552,	40.71691732,	41.15087704,	41.5698014,	41.97427823,	42.36437106,	42.73949048,	43.10022666,
                        43.44684334,	43.77997425,	44.09997652,	44.40639734,	44.70014094,	44.9828828,	45.25534722,	45.51753972,	45.76952054,
                        46.01080863,	46.24099832,	46.46149988,	46.67197949,	46.87167179,	47.06025867,	47.23759706,	47.4042231,	47.55977857,
                        47.70331261,	47.83424183,	47.95213361,	48.05662309,	48.14819698,	48.22769441,	48.29512055,	48.35035075,	48.39456011,
                        48.42852687,	48.45208394,	48.46515086,	48.46777338,	48.46078536,	48.44554151,	48.42189624,	48.3894521,	48.34818552,
                        48.29853694,	48.24064751,	48.17486423,	48.10123532,	48.01898928,	47.92796539,	47.82846007,	47.72136548,	47.60631259])

reserves_2022 = 880  # Initial reserves in 2022

# Initialize arrays to store the data
reserves = np.zeros_like(years, dtype=float)

# Set initial reserves
reserves[0] = reserves_2022

# Simulate depletion of reserves over time
for i in range(1, len(years)):
    delta_reserves = (production[i-1] - consumption[i-1]) + mining[i-1]
    reserves[i] = reserves[i-1] - delta_reserves

# Plotting the depletion of reserves over time
plt.figure(figsize=(10, 6))
plt.plot(years, reserves, color='black', marker='o', linestyle='-')
plt.title('Copper Reserves Depletion Over Time')
plt.xlabel('Year')
plt.ylabel('Reserves (Mt)')
plt.grid(True)
plt.show()

# Find the year at which reserves are fully depleted
depletion_year = years[np.where(reserves <= 0)[0][0]]

print("Year of Full Depletion:", depletion_year)
# Out:
# Year of Full Depletion: 2055

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given data
population = np.array([6.148898975, 6.230746982, 6.31240736, 6.393898365, 6.475751478, 6.558176119,
                       6.641416218, 6.725948544, 6.811597272, 6.898305908, 6.985603105, 7.073125425,
                       7.161697921, 7.25059337, 7.339013419, 7.426597537, 7.513474238, 7.599822404,
                       7.683789828, 7.764951032, 7.84095288, 7.909295151, 7.975105156])

consumption = np.array([15.122,	14.938,	15.133,	15.641,	16.743,	16.552,	16.917,	18.026,	17.877,	17.87,
                        19.136,	19.709,	20.479,	21.408,	22.906,	23.046,	23.481,	23.686,	24.466,	24.321,
                        24.945,	25.204,	26.069])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, population, consumption)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Sensitivity Analysis
k_values = np.linspace(k * 0.5, k * 1.5, 10)
alpha_values = np.linspace(alpha * 0.5, alpha * 1.5, 10)

plt.figure(figsize=(12, 8))

for i, k_val in enumerate(k_values):
    predicted_consumption = power_law_model(population, k_val, alpha)
    plt.plot(population, predicted_consumption, label=f'k = {k_val:.2f}', linestyle='--')

for i, alpha_val in enumerate(alpha_values):
    predicted_consumption = power_law_model(population, k, alpha_val)
    plt.plot(population, predicted_consumption, label=f'alpha = {alpha_val:.2f}', linestyle='-.')

plt.scatter(population, consumption, color='blue', label='Actual Data')
plt.title('Sensitivity Analysis of Power-law Model for Copper Consumption vs Population')
plt.xlabel('Population (billions)')
plt.ylabel('Consumption (Mt)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitted Parameters:
# k: 0.22920129758714317
# alpha: 2.283428131652162

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given data
population = np.array([6.148898975, 6.230746982, 6.31240736, 6.393898365, 6.475751478, 6.558176119,
                       6.641416218, 6.725948544, 6.811597272, 6.898305908, 6.985603105, 7.073125425,
                       7.161697921, 7.25059337, 7.339013419, 7.426597537, 7.513474238, 7.599822404,
                       7.683789828, 7.764951032, 7.84095288, 7.909295151, 7.975105156])

mining = np.array([13.2,	13.7,	13.6,	13.6,	14.6,	15,	15.1,	15.4,	15.4,	15.9,	15.9,	16.1,	16.9,
                   18.3,	18.5,	19.1,	20.1,	20,	20.4,	20.4,	20.6,	21.2,	21.9])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, population, mining)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Sensitivity Analysis
k_values = np.linspace(k * 0.5, k * 1.5, 10)
alpha_values = np.linspace(alpha * 0.5, alpha * 1.5, 10)

plt.figure(figsize=(12, 8))

for i, k_val in enumerate(k_values):
    predicted_mining = power_law_model(population, k_val, alpha)
    plt.plot(population, predicted_mining, label=f'k = {k_val:.2f}', linestyle='--')

for i, alpha_val in enumerate(alpha_values):
    predicted_mining = power_law_model(population, k, alpha_val)
    plt.plot(population, predicted_mining, label=f'alpha = {alpha_val:.2f}', linestyle='-.')

plt.scatter(population, mining, color='blue', label='Actual Data')
plt.title('Sensitivity Analysis of Power-law Model for Copper Mining vs Population')
plt.xlabel('Population (billions)')
plt.ylabel('Mining (Mt)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitted Parameters:
# k: 0.33518286439765077
# alpha: 2.008507433624112

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Given data
population = np.array([6.148898975, 6.230746982, 6.31240736, 6.393898365, 6.475751478, 6.558176119,
                       6.641416218, 6.725948544, 6.811597272, 6.898305908, 6.985603105, 7.073125425,
                       7.161697921, 7.25059337, 7.339013419, 7.426597537, 7.513474238, 7.599822404,
                       7.683789828, 7.764951032, 7.84095288, 7.909295151, 7.975105156])

production = np.array([14.793,	15.638,	15.354,	15.272,	15.918,	16.572,	17.288,	17.895,	18.191,	18.234,
                       18.981,	19.601,	20.194,	21.058,	22.49,	22.838,	23.356,	23.551,	24.062,	24.086,
                       24.546,	24.823,	25.664])

# Define the power-law function
def power_law_model(P, k, alpha):
    return k * np.power(P, alpha)

# Fit the model to the data
params, covariance = curve_fit(power_law_model, population, production)

# Extracting parameters
k, alpha = params

# Print the fitted parameters
print("Fitted Parameters:")
print("k:", k)
print("alpha:", alpha)

# Sensitivity Analysis
k_values = np.linspace(k * 0.5, k * 1.5, 10)
alpha_values = np.linspace(alpha * 0.5, alpha * 1.5, 10)

plt.figure(figsize=(12, 8))

for i, k_val in enumerate(k_values):
    predicted_production = power_law_model(population, k_val, alpha)
    plt.plot(population, predicted_production, label=f'k = {k_val:.2f}', linestyle='--')

for i, alpha_val in enumerate(alpha_values):
    predicted_production = power_law_model(population, k, alpha_val)
    plt.plot(population, predicted_production, label=f'alpha = {alpha_val:.2f}', linestyle='-.')

plt.scatter(population, production, color='blue', label='Actual Data')
plt.title('Sensitivity Analysis of Power-law Model for Copper Production vs Population')
plt.xlabel('Population (billions)')
plt.ylabel('Production (Mt)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitted Parameters:
# k: 0.262471870241196
# alpha: 2.2109461701252426
